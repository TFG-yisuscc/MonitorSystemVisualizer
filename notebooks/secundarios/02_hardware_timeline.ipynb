# %% [markdown]
# # Comparativa de hardware entre runs
#
# Vista panorámica de cómo se comporta el hardware (temperatura, potencia,
# CPU, memoria) durante la inferencia de distintos modelos.
#
# Cada columna del grid es un run. Esto permite comparar el régimen térmico,
# el consumo de potencia y la carga de CPU/memoria entre modelos que corren
# en la misma Raspberry Pi 5.
#
# ## Cómo usar este notebook
#
# 1. Coloca todos los runs en  (cada run en su propia subcarpeta).
# 2. *Run All*.

# %%
"""Carga todos los runs con hardware data."""

import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from monitorviz.io import load_collection
from monitorviz.transforms import RunCollection
from monitorviz.viz import setup_style

setup_style("talk")
warnings.filterwarnings("ignore", category=UserWarning, module="seaborn")
pd.set_option("display.max_columns", 50)

_here = Path.cwd()
PROJECT_ROOT = _here.parent.parent if _here.name == "secundarios" else (_here.parent if _here.name == "notebooks" else _here)
DATA_ROOT = PROJECT_ROOT / "data" / "TFG-DATA"

assert DATA_ROOT.is_dir(), f"❌ No encontrado: {DATA_ROOT.resolve()}"

coll = load_collection(DATA_ROOT)
hw_runs = RunCollection(runs=[r for r in coll if r.has_hardware_data])
print(f"Runs cargados: {len(coll)} total, {len(hw_runs)} con hardware data.")
for r in hw_runs:
    print(f"  • {r.model_short} ({r.summary.inference_engine}) — "
          f"{len(r.hw_samples)} muestras, {len(r.prompts)} prompts")
# Out:
# Non-positive prob en LLAMA tokenProb: 3938 tokens omitidos (run=1779665414914478319, prompt=0). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4018 tokens omitidos (run=1779665414914478319, prompt=1). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4016 tokens omitidos (run=1779665414914478319, prompt=2). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 3937 tokens omitidos (run=1779665414914478319, prompt=3). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4014 tokens omitidos (run=1779665414914478319, prompt=4). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 3929 tokens omitidos (run=1779665414914478319, prompt=5). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4010 tokens omitidos (run=1779665414914478319, prompt=6). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4002 tokens omitidos (run=1779665414914478319, prompt=7). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4060 tokens omitidos (run=1779665414914478319, prompt=8). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4000 tokens omitidos (run=1779665414914478319, prompt=9). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4050 tokens omitidos (run=1779665414914478319, prompt=10). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4024 tokens omitidos (run=1779665414914478319, prompt=11). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4024 tokens omitidos (run=1779665414914478319, prompt=12). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4036 tokens omitidos (run=1779665414914478319, prompt=13). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4056 tokens omitidos (run=1779665414914478319, prompt=14). Run posiblemente corrupto.
# tokenProb size mismatch in run=1780948937859414717 prompt=7: got 266 tokens, eval_count=-1
# Non-positive prob en LLAMA tokenProb: 3938 tokens omitidos (run=1780618433754296313, prompt=0). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4018 tokens omitidos (run=1780618433754296313, prompt=1). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4016 tokens omitidos (run=1780618433754296313, prompt=2). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 3937 tokens omitidos (run=1780618433754296313, prompt=3). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4014 tokens omitidos (run=1780618433754296313, prompt=4). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 3929 tokens omitidos (run=1780618433754296313, prompt=5). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4010 tokens omitidos (run=1780618433754296313, prompt=6). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4002 tokens omitidos (run=1780618433754296313, prompt=7). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4060 tokens omitidos (run=1780618433754296313, prompt=8). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4000 tokens omitidos (run=1780618433754296313, prompt=9). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4050 tokens omitidos (run=1780618433754296313, prompt=10). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4024 tokens omitidos (run=1780618433754296313, prompt=11). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4024 tokens omitidos (run=1780618433754296313, prompt=12). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4036 tokens omitidos (run=1780618433754296313, prompt=13). Run posiblemente corrupto.
# Non-positive prob en LLAMA tokenProb: 4056 tokens omitidos (run=1780618433754296313, prompt=14). Run posiblemente corrupto.
# tokenProb is not valid JSON for run=1780932981355222737 prompt=0: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780932981355222737 prompt=0: got 0 tokens, eval_count=512
# tokenProb is not valid JSON for run=1780932981355222737 prompt=1: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780932981355222737 prompt=1: got 0 tokens, eval_count=512
# tokenProb is not valid JSON for run=1780932981355222737 prompt=2: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780932981355222737 prompt=2: got 0 tokens, eval_count=512
# tokenProb is not valid JSON for run=1780932981355222737 prompt=3: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780932981355222737 prompt=3: got 0 tokens, eval_count=180
# tokenProb is not valid JSON for run=1780932981355222737 prompt=4: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780932981355222737 prompt=4: got 0 tokens, eval_count=231
# tokenProb is not valid JSON for run=1780932981355222737 prompt=5: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780932981355222737 prompt=5: got 0 tokens, eval_count=481
# tokenProb is not valid JSON for run=1780932981355222737 prompt=6: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780932981355222737 prompt=6: got 0 tokens, eval_count=512
# tokenProb is not valid JSON for run=1780932981355222737 prompt=7: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780932981355222737 prompt=7: got 0 tokens, eval_count=356
# tokenProb is not valid JSON for run=1780932981355222737 prompt=8: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780932981355222737 prompt=8: got 0 tokens, eval_count=335
# tokenProb is not valid JSON for run=1780932981355222737 prompt=9: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780932981355222737 prompt=9: got 0 tokens, eval_count=512
# tokenProb is not valid JSON for run=1780932981355222737 prompt=10: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780932981355222737 prompt=10: got 0 tokens, eval_count=512
# tokenProb is not valid JSON for run=1780932981355222737 prompt=11: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780932981355222737 prompt=11: got 0 tokens, eval_count=512
# tokenProb is not valid JSON for run=1780932981355222737 prompt=12: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780932981355222737 prompt=12: got 0 tokens, eval_count=324
# tokenProb is not valid JSON for run=1780932981355222737 prompt=13: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780932981355222737 prompt=13: got 0 tokens, eval_count=512
# tokenProb is not valid JSON for run=1780932981355222737 prompt=14: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780932981355222737 prompt=14: got 0 tokens, eval_count=460
# tokenProb is not valid JSON for run=1780935125511428751 prompt=0: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780935125511428751 prompt=0: got 0 tokens, eval_count=512
# tokenProb is not valid JSON for run=1780935125511428751 prompt=1: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780935125511428751 prompt=1: got 0 tokens, eval_count=512
# tokenProb is not valid JSON for run=1780935125511428751 prompt=2: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780935125511428751 prompt=2: got 0 tokens, eval_count=512
# tokenProb is not valid JSON for run=1780935125511428751 prompt=3: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780935125511428751 prompt=3: got 0 tokens, eval_count=192
# tokenProb is not valid JSON for run=1780935125511428751 prompt=4: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780935125511428751 prompt=4: got 0 tokens, eval_count=512
# tokenProb is not valid JSON for run=1780935125511428751 prompt=5: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780935125511428751 prompt=5: got 0 tokens, eval_count=512
# tokenProb is not valid JSON for run=1780935125511428751 prompt=6: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780935125511428751 prompt=6: got 0 tokens, eval_count=258
# tokenProb is not valid JSON for run=1780935125511428751 prompt=7: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780935125511428751 prompt=7: got 0 tokens, eval_count=387
# tokenProb is not valid JSON for run=1780935125511428751 prompt=8: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780935125511428751 prompt=8: got 0 tokens, eval_count=333
# tokenProb is not valid JSON for run=1780935125511428751 prompt=9: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780935125511428751 prompt=9: got 0 tokens, eval_count=512
# tokenProb is not valid JSON for run=1780935125511428751 prompt=10: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780935125511428751 prompt=10: got 0 tokens, eval_count=512
# tokenProb is not valid JSON for run=1780935125511428751 prompt=11: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780935125511428751 prompt=11: got 0 tokens, eval_count=512
# tokenProb is not valid JSON for run=1780935125511428751 prompt=12: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780935125511428751 prompt=12: got 0 tokens, eval_count=493
# tokenProb is not valid JSON for run=1780935125511428751 prompt=13: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780935125511428751 prompt=13: got 0 tokens, eval_count=512
# tokenProb is not valid JSON for run=1780935125511428751 prompt=14: Expecting value: line 1 column 1 (char 0)
# tokenProb size mismatch in run=1780935125511428751 prompt=14: got 0 tokens, eval_count=512
# Skipping run 1781290935558980955: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781290935558980955
# Skipping run 1781293123903975176: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781293123903975176
# Skipping run 1781298530628133515: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781298530628133515
# Skipping run 1781302859077980337: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781302859077980337
# Skipping run 1781304656626641668: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781304656626641668
# Skipping run 1781309343586089200: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781309343586089200
# Skipping run 1781314425685876517: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781314425685876517
# Skipping run 1781318091462136557: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781318091462136557
# Skipping run 1781319700008634024: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781319700008634024
# Skipping run 1781321910271908480: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781321910271908480
# Skipping run 1781324382433287461: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781324382433287461
# Skipping run 1781327343520255142: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781327343520255142
# Skipping run 1781335643387429955: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781335643387429955
# Skipping run 1781344244187298522: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781344244187298522
# Skipping run 1781344881768307565: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781344881768307565
# Skipping run 1781346797524154075: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781346797524154075
# Skipping run 1781348400404508246: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781348400404508246
# Skipping run 1781348896972852962: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781348896972852962
# Skipping run 1781350166515543624: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781350166515543624
# Skipping run 1781351507064371212: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781351507064371212
# Skipping run 1781352661462520159: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781352661462520159
# Skipping run 1781353084246348167: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781353084246348167
# Skipping run 1781353703770649822: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781353703770649822
# Skipping run 1781354420988751736: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781354420988751736
# Skipping run 1781355428909825502: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781355428909825502
# Skipping run 1781358566798618241: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781358566798618241
# Skipping run 1781359761068703049: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781359761068703049
# Skipping run 1781361352427432305: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781361352427432305
# Skipping run 1781363387069226882: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781363387069226882
# Skipping run 1781373292981490941: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781373292981490941
# Skipping run 1781374159678187419: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781374159678187419
# Skipping run 1781374486725447084: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781374486725447084
# Skipping run 1781374993867113641: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781374993867113641
# Skipping run 1781375559430791585: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781375559430791585
# Skipping run 1781376391978496791: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781376391978496791
# Skipping run 1781378804619931486: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781378804619931486
# Skipping run 1781419420616931495: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781419420616931495
# Skipping run 1781420663822607605: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781420663822607605
# Skipping run 1781422124723629104: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781422124723629104
# Skipping run 1781425907257301823: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781425907257301823
# Skipping run 1781428394918943175: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781428394918943175
# Skipping run 1781429295323251854: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781429295323251854
# Skipping run 1781430667842222699: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781430667842222699
# Skipping run 1781432286680402966: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781432286680402966
# Skipping run 1781434513354725487: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781434513354725487
# Skipping run 1781437144791281370: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781437144791281370
# Skipping run 1781438783671648025: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781438783671648025
# Skipping run 1781449444361182859: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781449444361182859
# Skipping run 1781452799510679938: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781452799510679938
# Skipping run 1781455121379429760: No *_prompt_metrics_*.jsonl in /home/yisus/PycharmProjects/Visualizer/data/TFG-DATA/Perplejidad/1781455121379429760
# Runs cargados: 259 total, 259 con hardware data.
#   • ministral:q4_k_m (OLLAMA) — 15070 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 13151 muestras, 15 prompts
#   • llama3.2_3b:q4_k_m (OLLAMA) — 4721 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 27875 muestras, 15 prompts
#   • llama3.2_1b:q4_k_m (OLLAMA) — 2107 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 12594 muestras, 15 prompts
#   • granite:q4_k_m (OLLAMA) — 5185 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5313 muestras, 15 prompts
#   • gemma:q4_k_m (OLLAMA) — 6194 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5978 muestras, 15 prompts
#   • deepseek:q4_k_m (OLLAMA) — 5228 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 20851 muestras, 15 prompts
#   • ministral:q4_k_m (OLLAMA) — 25481 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 22815 muestras, 15 prompts
#   • llama3.2_3b:q4_k_m (OLLAMA) — 9832 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 51009 muestras, 15 prompts
#   • llama3.2_1b:q4_k_m (OLLAMA) — 3599 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 20992 muestras, 15 prompts
#   • granite:q4_k_m (OLLAMA) — 9700 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 8585 muestras, 15 prompts
#   • gemma:q4_k_m (OLLAMA) — 12128 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 11167 muestras, 15 prompts
#   • deepseek:q4_k_m (OLLAMA) — 9810 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 36363 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q3_K_M (LLAMA) — 20975 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_0 (LLAMA) — 30091 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 21118 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q5_K_M (LLAMA) — 20991 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q8_0 (LLAMA) — 46032 muestras, 15 prompts
#   • granite-4.0-h-micro-Q3_K_M (LLAMA) — 4250 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_0 (LLAMA) — 4442 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5308 muestras, 15 prompts
#   • granite-4.0-h-micro-Q5_K_M (LLAMA) — 5631 muestras, 15 prompts
#   • granite-4.0-h-micro-Q8_0 (LLAMA) — 8660 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-BF16 (LLAMA) — 42916 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q3_K_M (LLAMA) — 17186 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_0 (LLAMA) — 14452 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 12444 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q5_K_M (LLAMA) — 6518 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q8_0 (LLAMA) — 13470 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q3_K_M (LLAMA) — 23823 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_0 (LLAMA) — 11146 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 27732 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q5_K_M (LLAMA) — 17780 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q8_0 (LLAMA) — 16592 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q3_K_M (LLAMA) — 10164 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_0 (LLAMA) — 10998 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 13164 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q5_K_M (LLAMA) — 13219 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q8_0 (LLAMA) — 10959 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q3_K_M (LLAMA) — 13015 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_0 (LLAMA) — 8281 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 6028 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q5_K_M (LLAMA) — 5949 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q8_0 (LLAMA) — 8479 muestras, 15 prompts
#   • ministral:q4_k_m (OLLAMA) — 25481 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 22815 muestras, 15 prompts
#   • llama3.2_3b:q4_k_m (OLLAMA) — 9832 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 51009 muestras, 15 prompts
#   • llama3.2_1b:q4_k_m (OLLAMA) — 3599 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 20992 muestras, 15 prompts
#   • granite:q4_k_m (OLLAMA) — 9700 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 8585 muestras, 15 prompts
#   • gemma:q4_k_m (OLLAMA) — 12128 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 11167 muestras, 15 prompts
#   • deepseek:q4_k_m (OLLAMA) — 9810 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 36363 muestras, 15 prompts
#   • ministral:q4_k_m (OLLAMA) — 15070 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 13151 muestras, 15 prompts
#   • llama3.2_3b:q4_k_m (OLLAMA) — 4721 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 27875 muestras, 15 prompts
#   • llama3.2_1b:q4_k_m (OLLAMA) — 2107 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 12594 muestras, 15 prompts
#   • granite:q4_k_m (OLLAMA) — 5185 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5313 muestras, 15 prompts
#   • gemma:q4_k_m (OLLAMA) — 6194 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5978 muestras, 15 prompts
#   • deepseek:q4_k_m (OLLAMA) — 5228 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 20851 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 2432 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 4124 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 4532 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 1735 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 4362 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 4309 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 5164 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5980 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5270 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 2989 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 7694 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 6601 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 10341 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 6004 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5312 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 5547 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 13164 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 8882 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 20767 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5973 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5317 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 12485 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 27761 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 13139 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 26923 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5979 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5308 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 16968 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 38418 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 16228 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 20461 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5980 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5312 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 12532 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 27979 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 13124 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 21025 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 6011 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5298 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 12554 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 27808 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 13203 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 20844 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5971 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5311 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 12548 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 27977 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 13239 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 20886 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5981 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5305 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 12508 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 27870 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 13202 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 20939 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5965 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5311 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 12548 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 27891 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 13249 muestras, 15 prompts
#   • ministral:q4_k_m (OLLAMA) — 17920 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 13227 muestras, 15 prompts
#   • llama3.2_3b:q4_k_m (OLLAMA) — 4747 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 27944 muestras, 15 prompts
#   • llama3.2_1b:q4_k_m (OLLAMA) — 2108 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 12531 muestras, 15 prompts
#   • granite:q4_k_m (OLLAMA) — 5203 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5298 muestras, 15 prompts
#   • gemma:q4_k_m (OLLAMA) — 6247 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5986 muestras, 15 prompts
#   • deepseek:q4_k_m (OLLAMA) — 5231 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 21280 muestras, 15 prompts
#   • ministral:q4_k_m (OLLAMA) — 29033 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 22525 muestras, 15 prompts
#   • llama3.2_3b:q4_k_m (OLLAMA) — 8958 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 46093 muestras, 15 prompts
#   • llama3.2_1b:q4_k_m (OLLAMA) — 3335 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 19779 muestras, 15 prompts
#   • granite:q4_k_m (OLLAMA) — 8623 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 8296 muestras, 15 prompts
#   • gemma:q4_k_m (OLLAMA) — 11712 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 11316 muestras, 15 prompts
#   • deepseek:q4_k_m (OLLAMA) — 11197 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 44067 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q3_K_M (LLAMA) — 20700 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_0 (LLAMA) — 30200 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 21445 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q5_K_M (LLAMA) — 15690 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q8_0 (LLAMA) — 45533 muestras, 15 prompts
#   • granite-4.0-h-micro-Q3_K_M (LLAMA) — 4264 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_0 (LLAMA) — 4444 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5301 muestras, 15 prompts
#   • granite-4.0-h-micro-Q5_K_M (LLAMA) — 5626 muestras, 15 prompts
#   • granite-4.0-h-micro-Q8_0 (LLAMA) — 8671 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-BF16 (LLAMA) — 45943 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q3_K_M (LLAMA) — 17290 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_0 (LLAMA) — 14397 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 11267 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q5_K_M (LLAMA) — 6516 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q8_0 (LLAMA) — 13442 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q3_K_M (LLAMA) — 23787 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_0 (LLAMA) — 24894 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 28040 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q5_K_M (LLAMA) — 17719 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q8_0 (LLAMA) — 16499 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q3_K_M (LLAMA) — 10158 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_0 (LLAMA) — 11033 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 6531 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q5_K_M (LLAMA) — 9882 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q8_0 (LLAMA) — 10962 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q3_K_M (LLAMA) — 12993 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_0 (LLAMA) — 11025 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 6035 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q5_K_M (LLAMA) — 5948 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q8_0 (LLAMA) — 8538 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 2438 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 4136 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 4537 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 1734 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 4361 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 4301 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 5167 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5970 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5255 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 2983 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 7705 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 6587 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 10335 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5978 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5280 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 5535 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 13148 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 8856 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 21012 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5982 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5244 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 12371 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 28034 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 13218 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 26798 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5990 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5300 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 17045 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 38496 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 16376 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 21059 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5984 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5314 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 12490 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 27878 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 13189 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 20825 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5953 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5205 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 12340 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 27861 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 13125 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 20940 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5967 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5304 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 12513 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 27728 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 13173 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 21160 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5977 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5302 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 12485 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 27964 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 13235 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 20607 muestras, 15 prompts
#   • gemma-4.5B-3n-E2B-it-Q4_K_M (LLAMA) — 5973 muestras, 15 prompts
#   • granite-4.0-h-micro-Q4_K_M (LLAMA) — 5254 muestras, 15 prompts
#   • Llama-3.2-1B-Instruct-Q4_K_M (LLAMA) — 12305 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 27810 muestras, 15 prompts
#   • Ministral-3-3B-Instruct-2512-Q4_K_M (LLAMA) — 13194 muestras, 15 prompts
#   • DeepSeek-R1-Distill-Qwen-1.5B-Q4_K_M (LLAMA) — 10332 muestras, 15 prompts
#   • Llama-3.2-3B-Instruct-Q4_K_M (LLAMA) — 12947 muestras, 15 prompts
#   • deepseek_r1_distill_qwen:1.5b (HAILO_OLLAMA) — 3938 muestras, 15 prompts
#   • llama3.2:3b (HAILO_OLLAMA) — 10401 muestras, 15 prompts
#   • deepseek:q4_k_m (OLLAMA) — 512 muestras, 1 prompts

# %% [markdown]
# ## Temperatura a lo largo del run
#
# Cada panel es un modelo. Se puede observar:
# - Velocidad de calentamiento inicial (rampa).
# - Temperatura de saturación (plateau).
# - Si alcanza el umbral de throttling (~80 °C).

# %%
hw_df = hw_runs.hw_metrics_df()

g = sns.relplot(
    data=hw_df, kind="line",
    x="t_rel_s", y="temperature_c",
    col="model_label", col_wrap=2,
    height=4.5, aspect=1.8,
    facet_kws={"sharey": True},
)
g.set_xlabels("Tiempo (s)")
g.set_ylabels("Temperatura (°C)")
g.set_titles("{col_name}")
for ax in g.axes.flat:
    ax.axhline(80, ls="--", color="gray", alpha=0.5, label="80 °C")
g.fig.suptitle("Temperatura por modelo", y=1.02)
plt.show()

# %% [markdown]
# ## Potencia interna
#
# El consumo de potencia correlaciona directamente con la carga computacional.
# Modelos más grandes consumen más. La potencia base (idle, antes de que empiece
# la inferencia) es ~3 W en la RPi5.

# %%
g = sns.relplot(
    data=hw_df, kind="line",
    x="t_rel_s", y="internal_power_w",
    col="model_label", col_wrap=2,
    height=4.5, aspect=1.8,
    facet_kws={"sharey": True},
)
g.set_xlabels("Tiempo (s)")
g.set_ylabels("Potencia (W)")
g.set_titles("{col_name}")
g.fig.suptitle("Potencia interna por modelo", y=1.02)
plt.show()

# %% [markdown]
# ## CPU y memoria
#
# El uso de CPU durante inferencia en CPU-only es típicamente ~100%.
# La memoria interesa para ver si el modelo cabe en RAM o se produce
# paginación a swap.

# %%
hw_inference = hw_df[hw_df["cpu_usage_pct"] > 50]

fig, axes = plt.subplots(2, 1, figsize=(12, 9))

order = hw_df.groupby("model_label")["cpu_usage_pct"].median().sort_values(ascending=False).index

sns.boxplot(
    data=hw_inference, x="model_label", y="cpu_usage_pct",
    order=order, showfliers=False, ax=axes[0],
)
axes[0].set_title("Distribución de CPU durante inferencia (% muestras con CPU > 50%)")
axes[0].set_xlabel("")
axes[0].set_ylabel("CPU (%)")
axes[0].set_ylim(80, 102)

sns.boxplot(
    data=hw_df, x="model_label", y="mem_pct",
    order=order, showfliers=False, ax=axes[1],
)
axes[1].set_title("Distribución de memoria (%)")
axes[1].set_xlabel("")
axes[1].set_ylabel("Memoria (%)")

fig.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 10))

order = (hw_df.groupby("model_label")["cpu_usage_pct"]
         .median().sort_values(ascending=False).index.tolist())

# CPU — violin + strip
active = hw_df[hw_df["cpu_usage_pct"] > 50]
sns.violinplot(data=active, x="model_label", y="cpu_usage_pct",
               order=order, inner=None, alpha=0.6, ax=axes[0])
sns.stripplot(data=active, x="model_label", y="cpu_usage_pct",
              order=order, size=2, alpha=0.3, color="black", ax=axes[0])
axes[0].set_title("Distribución de CPU durante inferencia")
axes[0].set_xlabel("")
axes[0].set_ylabel("CPU (%)")
axes[0].set_ylim(80, 102)

# Memoria — violin + strip (todas las muestras, no solo activas)
mem_order = (hw_df.groupby("model_label")["mem_pct"]
             .median().sort_values(ascending=False).index.tolist())
sns.violinplot(data=hw_df, x="model_label", y="mem_pct",
               order=mem_order, inner=None, alpha=0.6, ax=axes[1])
sns.stripplot(data=hw_df, x="model_label", y="mem_pct",
              order=mem_order, size=2, alpha=0.3, color="black", ax=axes[1])
axes[1].set_title("Distribución de memoria (%)")
axes[1].set_xlabel("")
axes[1].set_ylabel("Memoria (%)")

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Throttling
#
# Porcentaje de muestras con throttling activo por modelo. Un valor > 0
# indica que el hardware está limitando el rendimiento por protección térmica.

# %%
throttle_summary = (
    hw_df.groupby("model_short")["throt_any_active"]
    .agg(["sum", "count"])
    .assign(ratio_pct=lambda d: d["sum"] / d["count"] * 100)
    .rename(columns={"sum": "muestras_throttled", "count": "total_muestras"})
    .round(2)
)
throttle_summary

# %% [markdown]
# ## Swap bajo carga
#
# Si algún modelo fuerza el uso de swap, se notará aquí como un aumento
# sostenido durante la inferencia.

# %%
g = sns.relplot(
    data=hw_df, kind="line",
    x="t_rel_s", y="swap_pct",
    col="model_label", col_wrap=2,
    height=4, aspect=1.8,
    facet_kws={"sharey": True},
)
g.set_xlabels("Tiempo (s)")
g.set_ylabels("Swap (%)")
g.set_titles("{col_name}")
g.fig.suptitle("Uso de swap por modelo", y=1.02)
plt.show()

# %% [markdown]
# ## Temperatura y frecuencia (Benoit-Cattin et al., 2020)
#
# La siguiente visualización reproduce el esquema de análisis térmico de
# Benoit-Cattin et al. (2020): temperatura CPU (eje izquierdo) y frecuencia
# media (eje derecho) a lo largo del tiempo. El throttling térmico se
# manifiesta como una reducción de frecuencia cuando la temperatura supera
# los 80 °C.
#
# Además se muestra la variante B de la Fig. 2.16 del TFG (RAM + CPU con
# líneas verticales de fase) y el panel de histogramas de métricas hw.

# %%
from monitorviz.transforms import hw_metrics_to_df
from monitorviz.viz import cpu_memory_dual_phases, hw_distributions_panel, temp_freq_dual

for r in hw_runs.runs:
    hw = hw_runs.hw_metrics_df()
    hw_r = hw[hw["run_id"] == r.run_id]
    if hw_r.empty:
        continue

    # Temp + freq dual Y (Benoit-Cattin panel i)
    fig = temp_freq_dual(hw_r, r, title=f"Temp y frecuencia — {r.model_short}")
    plt.show()

    # RAM + CPU con líneas de fase (Fig. 2.16 variante B)
    fig = cpu_memory_dual_phases(hw_r, r, title=f"RAM y CPU (fases) — {r.model_short}")
    plt.show()

    # Histogramas hw (Benoit-Cattin panel iii)
    fig = hw_distributions_panel(hw_r, r, title=f"Distribución hw — {r.model_short}")
    plt.show()

# %% [markdown]
# # Comparativa de métricas hardware por modelo
#
# Barplot agrupado de cuatro métricas hardware clave, agrupadas por modelo
# y coloreadas por configuración (ventilador activo / sin ventilador).
# Inspirado en Velasco-Montero et al. (2022), Cap. 4, Fig. 4.5.
#
# Cuando estén disponibles runs con fan=False (Experimento E0), aparecerá
# la barra comparativa. Con los datos actuales (fan=True) se muestra una
# barra por modelo.

# %%
import re
import numpy as np

def _plot_label(model_short: str, engine: str) -> str:
    """Abbreviate model name for axis labels."""
    name = model_short
    name = re.sub(r'-Q\d_K_[MS].*', '', name)       # -Q4_K_M suffix
    name = re.sub(r':q\d_k_[ms]$', '', name)         # :q4_k_m suffix
    name = re.sub(r'-Instruct', '', name)
    name = re.sub(r'-2512', '', name)
    name = re.sub(r'-Distill-Qwen', '', name)
    name = re.sub(r'-3n-E2B-it', '', name)           # gemma specific
    name = re.sub(r'-h-micro', '', name)              # granite specific
    name = re.sub(r'_', '.', name)
    name = name.strip('-')
    suffix = "O" if engine == "OLLAMA" else "L"
    return f"{name} ({suffix})"

# Agregar métricas hw por run
hw_full = coll.hw_metrics_df()
pm_full = coll.prompt_metrics_df()

hw_summary_rows = []
for r in coll.runs:
    hw_r = hw_full[hw_full["run_id"] == r.run_id]
    pm_r = pm_full[
        (pm_full["run_id"] == r.run_id) &
        (~pm_full["is_empty_generation"]) &
        (pm_full["latency_ms"] > 0)
    ]
    if hw_r.empty:
        continue
    active = hw_r[hw_r["cpu_usage_pct"] > 50]
    fan_label = "Con ventilador" if r.meta.fan else "Sin ventilador"
    hw_summary_rows.append({
        "model":    _plot_label(r.model_short, r.summary.inference_engine),
        "config":   fan_label,
        "cpu_pct":  active["cpu_usage_pct"].mean() if not active.empty else float("nan"),
        "tokens_s": pm_r["tokens_per_second"].mean() if not pm_r.empty else float("nan"),
        "power_w":  hw_r["internal_power_w"].mean(),
        "mem_mb":   (hw_r["mem_used_bytes"].mean() / (1024**2)) if not hw_r.empty else float("nan"),
    })

hw_summary = pd.DataFrame(hw_summary_rows)

METRICS = [
    ("cpu_pct",   "CPU media (%)",      "(a)", (50, 105)),
    ("tokens_s",  "Throughput (tok/s)", "(b)", None),
    ("power_w",   "Potencia (W)",       "(c)", None),
    ("mem_mb",    "Memoria (MB)",       "(d)", None),
]

models  = sorted(hw_summary["model"].unique())
configs = sorted(hw_summary["config"].unique())
colors  = ["steelblue", "tomato", "seagreen", "goldenrod"]
x_pos   = np.arange(len(models))
n_cfg   = len(configs)
width   = 0.75 / max(n_cfg, 1)

fig, axes = plt.subplots(len(METRICS), 1, figsize=(12, 4 * len(METRICS)))
if len(METRICS) == 1:
    axes = [axes]

for ax, (col, ylabel, label, ylim) in zip(axes, METRICS):
    data = hw_summary.dropna(subset=[col])
    for i, (cfg, color) in enumerate(zip(configs, colors)):
        vals = []
        for m in models:
            sub = data[(data["model"] == m) & (data["config"] == cfg)]
            vals.append(sub[col].mean() if not sub.empty else float("nan"))
        offset = (i - n_cfg / 2 + 0.5) * width
        ax.bar(x_pos + offset, vals, width * 0.9,
               label=cfg, color=color, alpha=0.85)
    ax.set_xticks(x_pos)
    ax.set_xticklabels(models, rotation=45, ha="right")
    ax.set_ylabel(ylabel)
    if ylim:
        ax.set_ylim(*ylim)
    ax.text(-0.06, 1.03, label, transform=ax.transAxes,
            fontweight="bold", fontsize=12)
    if col == "cpu_pct":
        ax.legend(loc="upper right")

fig.suptitle(
    "Métricas hardware por modelo y configuración de refrigeración",
    y=1.01, fontsize=13
)
fig.tight_layout()
plt.show()
